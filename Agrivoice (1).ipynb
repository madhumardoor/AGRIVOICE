# %%
import pdfplumber

# Path to the uploaded file
pdf_path ="F:\\MLT NOTES\\zeopto\\k-10\\0000950170-23-001409-xbrl\\project\\PMKisanSamanNidhi.pdf"
pdf_path
# Out:
# 'F:\\MLT NOTES\\zeopto\\k-10\\0000950170-23-001409-xbrl\\project\\PMKisanSamanNidhi.pdf'

# %%
# Extract text from the PDF
def extract_text_from_pdf(pdf_path):
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            extracted_text = page.extract_text()
            if extracted_text:  # Ensure page has text
                text += extracted_text + "\n\n"
    return text

# %%
# Run the function and save the extracted text
policy_text = extract_text_from_pdf(pdf_path)

# %%
# Save extracted text to a file
text_file_path ="F:\\MLT NOTES\\zeopto\\k-10\\0000950170-23-001409-xbrl\\project\\PMKisanSamanNidhi.pd"

with open(text_file_path, "w", encoding="utf-8") as file:
    file.write(policy_text)

print("Text extraction complete. Saved to:", text_file_path)
# Out:
# Text extraction complete. Saved to: F:\MLT NOTES\zeopto\k-10\0000950170-23-001409-xbrl\project\PMKisanSamanNidhi.pd

# %%
import re
import nltk
from nltk.corpus import stopwords

# Download stopwords
nltk.download("stopwords")
stop_words = set(stopwords.words("english"))

# Function to clean text
def clean_text(text):
    text = re.sub(r"\s+", " ", text)  # Remove extra spaces
    text = re.sub(r"[^a-zA-Z0-9.,\n\s]", "", text)  # Remove special characters
    text = text.lower()  # Convert to lowercase
    text = " ".join([word for word in text.split() if word not in stop_words])  # Remove stopwords
    return text

# Apply text cleaning
cleaned_policy_text = clean_text(policy_text)

# Save cleaned text
clean_text_file ="F:\\MLT NOTES\\zeopto\\k-10\\0000950170-23-001409-xbrl\\project\\PMKisanSamanNidhi.pdf"
with open(clean_text_file, "w", encoding="utf-8") as file:
    file.write(cleaned_policy_text)

print("Text cleaning complete. Saved to:", clean_text_file)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# Text cleaning complete. Saved to: F:\MLT NOTES\zeopto\k-10\0000950170-23-001409-xbrl\project\PMKisanSamanNidhi.pdf

# %%
# Function to clean text
def clean_text(text):
    text = re.sub(r"\s+", " ", text)  # Remove extra spaces
    text = re.sub(r"[^a-zA-Z0-9.,\n\s]", "", text)  # Remove special characters
    text = text.lower()  # Convert to lowercase
    text = " ".join([word for word in text.split() if word not in stop_words])  # Remove stopwords
    return text

# %%
# Apply text cleaning
cleaned_policy_text = clean_text(policy_text)

# Save cleaned text
clean_text_file ="F:\\MLT NOTES\\zeopto\\k-10\\0000950170-23-001409-xbrl\\PMKisanSamanNidhi.pdf"
with open(clean_text_file, "w", encoding="utf-8") as file:
    file.write(cleaned_policy_text)

print("Text cleaning complete. Saved to:", clean_text_file)
# Out:
# Text cleaning complete. Saved to: F:\MLT NOTES\zeopto\k-10\0000950170-23-001409-xbrl\PMKisanSamanNidhi.pdf

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

nltk.download("punkt")  # Download tokenizer models

# Tokenize into sentences
sentences = sent_tokenize(cleaned_policy_text)

# Tokenize into words
words = word_tokenize(cleaned_policy_text)

print("Sample Sentences:", sentences[:3])
print("Sample Words:", words[:10])
# Out:
# Sample Sentences: ['pradhan mantri kisan samman nidhi pmkisan objective view augment income small marginal farmers smfs, government launched new central sector scheme, namely, pradhan mantri kisan samman nidhi pmkisan current financial year.', 'pmkisan scheme aims supplement financial needs smfs procuring various inputs ensure proper crop health appropriate yields, commensurate anticipated farm income end crop cycle.', 'would also protect falling clutches moneylenders meeting expenses ensure continuance farming activities.']
# Sample Words: ['pradhan', 'mantri', 'kisan', 'samman', 'nidhi', 'pmkisan', 'objective', 'view', 'augment', 'income']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from deep_translator import GoogleTranslator

# Translate text to Hindi
translated_text = GoogleTranslator(source="auto", target="hi").translate(cleaned_policy_text)

# Save translated text
translated_text_file ="F:\\MLT NOTES\\zeopto\\k-10\\0000950170-23-001409-xbrl\\project\\PMKisanSamanNidhi.pdf"
with open(translated_text_file, "w", encoding="utf-8") as file:
    file.write(translated_text)

print("Translation complete. Saved to:", translated_text_file)
# Out:
# Translation complete. Saved to: F:\MLT NOTES\zeopto\k-10\0000950170-23-001409-xbrl\project\PMKisanSamanNidhi.pdf

# %%
from deep_translator import GoogleTranslator

def split_text(text, chunk_size=500):
    return [text[i:i+chunk_size] for i in range(0, len(text), chunk_size)]

chunks = split_text(policy_text)
translated_chunks = []

for chunk in chunks:
    try:
        translated_chunks.append(GoogleTranslator(source="en", target="kn").translate(chunk))
    except Exception as e:
        print(f"Translation failed for chunk: {chunk[:50]}... Error: {e}")

translated_text = " ".join(translated_chunks)
print(translated_text)
# Out:
# ಪ್ರಧಾನ್ ಮಂತ್ರಿ ಕಿಸಾನ್ ಸಮ್ಮ್ಮನ್ ನಿಧಿ (ಪಿಎಂ-ಕಿಸಾನ್)
# ಉದ್ದೇಶಪೂರ್ವಕ
# The ಸಣ್ಣ ಮತ್ತು ಕನಿಷ್ಠ ರೈತರ (ಎಸ್‌ಎಂಎಫ್‌ಗಳು) ಆದಾಯವನ್ನು ಹೆಚ್ಚಿಸುವ ದೃಷ್ಟಿಯಿಂದ, ದಿ
# ಸರ್ಕಾರವು ಹೊಸ ಕೇಂದ್ರ ವಲಯದ ಯೋಜನೆಯನ್ನು ಪ್ರಾರಂಭಿಸಿದೆ, ಅವುಗಳೆಂದರೆ, “ಪ್ರಧಾನ್ ಮಂತ್ರಿ
# ಪ್ರಸಕ್ತ ಹಣಕಾಸು ವರ್ಷದಲ್ಲಿ ಕಿಸಾನ್ ಸಮ್ಮನ್ ನಿಧಿ (ಪಿಎಂ-ಕಿಸಾನ್) ”.
# PM ಪಿಎಂ-ಕಿಸಾನ್ ಯೋಜನೆ ಎಸ್‌ಎಂಎಫ್‌ಗಳ ಹಣಕಾಸಿನ ಅಗತ್ಯಗಳನ್ನು ಪೂರೈಸುವ ಗುರಿಯನ್ನು ಹೊಂದಿದೆ
# ಸರಿಯಾದ ಬೆಳೆ ಆರೋಗ್ಯ ಮತ್ತು ಸೂಕ್ತ ಇಳುವರಿಯನ್ನು ಖಚಿತಪಡಿಸಿಕೊಳ್ಳಲು ವಿವಿಧ ಒಳಹರಿವುಗಳನ್ನು ಸಂಗ್ರಹಿಸುವುದು,
# ಪ್ರತಿ ಸಿ ಕೊನೆಯಲ್ಲಿ ನಿರೀಕ್ಷಿತ ಕೃಷಿ ಆದಾಯದೊಂದಿಗೆ ಪ್ರಾರಂಭವಾಗುತ್ತದೆ ರಾಪ್ ಸೈಕಲ್.
#  ಇದು ಸಭೆಗಾಗಿ ಹಣದಾಸೆದಾರರ ಹಿಡಿತದಲ್ಲಿ ಬೀಳದಂತೆ ಅವರನ್ನು ರಕ್ಷಿಸುತ್ತದೆ
# ಅಂತಹ ವೆಚ್ಚಗಳು ಮತ್ತು ಕೃಷಿ ಚಟುವಟಿಕೆಗಳಲ್ಲಿ ಅವುಗಳ ನಿರಂತರತೆಯನ್ನು ಖಚಿತಪಡಿಸುತ್ತದೆ.
# ಕಟ್-ಆಫ್ ದಿನಾಂಕ
# El ಅರ್ಹರಿಗೆ ಲಾಭವನ್ನು ವರ್ಗಾಯಿಸಲು ಈ ಯೋಜನೆ 01.12.2018 ರಿಂದ ಪರಿಣಾಮಕಾರಿಯಾಗಿರುತ್ತದೆ
# ಫಲಾನುಭವಿಗಳು.
# Of ಫಲಾನುಭವಿಗಳ ಅರ್ಹತೆಯನ್ನು ನಿರ್ಧರಿಸುವ ಕಟ್-ಆಫ್ ದಿನಾಂಕವನ್ನು ಹೀಗೆ ಇರಿಸಲಾಗಿದೆ
# 01.02.2019.
# The ಮುಂದಿನ 5 ರ ಯೋಜನೆಯಡಿ ಲಾಭದ ಅರ್ಹತೆಗಾಗಿ ಕಟ್-ಆಫ್ ದಿನಾಂಕದಲ್ಲಿ ಬದಲಾವಣೆಗಳು, ಯಾವುದಾದರೂ ಇದ್ದರೆ
# ...

# %%
translated_text_file = "F:\\MLT NOTES\\zeopto\\k-10\\0000950170-23-001409-xbrl\\project\\PMKisanSamanNidhi_Kannada.txt"

with open(translated_text_file, "w", encoding="utf-8") as file:
    file.write(translated_text)

print("Kannada translation saved to:", translated_text_file)
# Out:
# Kannada translation saved to: F:\MLT NOTES\zeopto\k-10\0000950170-23-001409-xbrl\project\PMKisanSamanNidhi_Kannada.txt

# %%
from gtts import gTTS

tts = gTTS(translated_text, lang="kn")
tts.save("Kannada_Speech.mp3")

print("Kannada speech saved as Kannada_Speech.mp3")
# Out:
# Kannada speech saved as Kannada_Speech.mp3

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from collections import Counter

# Ensure required NLTK packages are downloaded
nltk.download("punkt")

# Load the translated Kannada text file
kannada_text_file = "F:/MLT NOTES/zeopto/k-10/0000950170-23-001409-xbrl/project/PMKisanSamanNidhi_Kannada.txt"
with open(kannada_text_file, "r", encoding="utf-8") as file:
    kannada_text = file.read()

# Sentence tokenization
sentences = sent_tokenize(kannada_text)

# Word tokenization and frequency count
words = word_tokenize(kannada_text)
word_freq = Counter(words)

# Sentence scoring based on word importance
sentence_scores = {sent: sum(word_freq[word] for word in word_tokenize(sent)) for sent in sentences}

# Select top 5 important sentences
summary_sentences = sorted(sentence_scores, key=sentence_scores.get, reverse=True)[:5]
summary = " ".join(summary_sentences)

# Save summarized text
summary_file = "F:/MLT NOTES/zeopto/k-10/0000950170-23-001409-xbrl/project/PMKisanSamanNidhi_Summary_Kannada.txt"
with open(summary_file, "w", encoding="utf-8") as file:
    file.write(summary)

print("Summary saved successfully!")
# Out:
# Summary saved successfully!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from gtts import gTTS

# Load summarized Kannada text
summary_file = "F:/MLT NOTES/zeopto/k-10/0000950170-23-001409-xbrl/project/PMKisanSamanNidhi_Summary_Kannada.txt"
with open(summary_file, "r", encoding="utf-8") as file:
    summary_text = file.read()

# Convert to speech
tts = gTTS(summary_text, lang="kn")
tts.save("PMKisanSamanNidhi_Summary_Kannada.mp3")

print("Kannada summary speech saved as PMKisanSamanNidhi_Summary_Kannada.mp3")
# Out:
# Kannada summary speech saved as PMKisanSamanNidhi_Summary_Kannada.mp3

# %%
Translation O

# %%
import os

output_folder = "F:/MLT NOTES/zeopto/k-10/0000950170-23-001409-xbrl/project/processed_policies"

# Get all summary files
summary_files = [f for f in os.listdir(output_folder) if f.endswith("_Summary_Kannada.txt")]
audio_files = [f.replace(".txt", ".mp3") for f in summary_files]  # Matching MP3 files

for summary_file, audio_file in zip(summary_files, audio_files):
    summary_path = os.path.join(output_folder, summary_file)
    audio_path = os.path.join(output_folder, audio_file)

    print(f"\n📄 **Summary of {summary_file.replace('_Summary_Kannada.txt', '')}:**\n")
    
    # Read and print the summary
    with open(summary_path, "r", encoding="utf-8") as file:
        print(file.read())

    # Play the audio file
    os.system(f'start "{audio_path}"')  # This will open the MP3 file using the default media player
# Out:
# 📄 **Summary of FAO Agriculture Policy Reports:**
#
# ...

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

def evaluate_translation(reference, candidate):
    reference_tokens = [reference.split()]
    candidate_tokens = candidate.split()
    
    # Apply smoothing to avoid zero division errors
    smoothie = SmoothingFunction().method1  
    score = sentence_bleu(reference_tokens, candidate_tokens, smoothing_function=smoothie)
    
    return score

# %%
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction

def evaluate_translation(reference, candidate):
    reference_tokens = [[word for word in reference.split()]]  # List of lists
    candidate_tokens = [word for word in candidate.split()]  # Single list
    
    # Apply smoothing to avoid zero-division errors
    smoothie = SmoothingFunction().method1  
    score = corpus_bleu([reference_tokens], [candidate_tokens], smoothing_function=smoothie)
    
    return score
